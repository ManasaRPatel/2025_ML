# %% [markdown]
# <a href="https://colab.research.google.com/github/ManasaRPatel/2025_ML/blob/main/mse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate data
X = np.linspace(0, 10, 50)       # 50 points between 0 and 10
y = 2 * X + 1 + np.random.randn(50)  # y = 2x + 1 + noise

# %%
plt.scatter(X, y)
plt.xlabel("X")
plt.ylabel("y")
plt.title("Data Points")
plt.show()

# %%
# Initialize parameters
w = 0.0
b = 0.0
learning_rate = 0.01
epochs = 1000

# %%
def mse(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# %%
n = len(X)

# Gradient Descent loop
for i in range(epochs):
    y_pred = w * X + b
    error = y_pred - y

    # Compute gradients
    dw = (2/n) * np.dot(error, X)
    db = (2/n) * np.sum(error)

    # Update parameters
    w -= learning_rate * dw
    b -= learning_rate * db

    # Optional: print progress every 100 steps
    if i % 100 == 0:
        print(f"Epoch {i}: w={w:.3f}, b={b:.3f}, MSE={mse(y, y_pred):.3f}")
# Out:
# Epoch 0: w=1.466, b=0.222, MSE=160.571
# Epoch 100: w=2.095, b=0.553, MSE=0.859
# Epoch 200: w=2.074, b=0.692, MSE=0.839
# Epoch 300: w=2.061, b=0.776, MSE=0.831
# Epoch 400: w=2.054, b=0.827, MSE=0.828
# Epoch 500: w=2.049, b=0.858, MSE=0.827
# Epoch 600: w=2.047, b=0.876, MSE=0.827
# Epoch 700: w=2.045, b=0.887, MSE=0.827
# Epoch 800: w=2.044, b=0.894, MSE=0.827
# Epoch 900: w=2.043, b=0.898, MSE=0.827

# %%
y_pred_final = w * X + b

plt.scatter(X, y, label='Data')
plt.plot(X, y_pred_final, color='red', label='Best Fit Line')
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()

print(f"Final Model: y = {w:.2f}x + {b:.2f}")
# Out:
# Final Model: y = 2.04x + 0.90

# %%
final_mse = mse(y, y_pred_final)
print(f"Final Mean Squared Error: {final_mse:.3f}")
# Out:
# Final Mean Squared Error: 0.827
