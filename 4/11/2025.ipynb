# %% [markdown]
# <a href="https://colab.research.google.com/github/ManasaRPatel/2025_ML/blob/main/4/11/2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate data
X = np.linspace(0, 10, 50)       # 50 points between 0 and 10
y = 2 * X + 1 + np.random.randn(50)  # y = 2x + 1 + noise

# %%
plt.scatter(X, y)
plt.xlabel("X")
plt.ylabel("y")
plt.title("Data Points")
plt.show()

# %%
# Initialize parameters
w = 0.0
b = 0.0
learning_rate = 0.01
epochs = 1000

# %%
def mse(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# %%
n = len(X)

# Gradient Descent loop
for i in range(epochs):
    y_pred = w * X + b
    error = y_pred - y

    # Compute gradients
    dw = (2/n) * np.dot(error, X)
    db = (2/n) * np.sum(error)

    # Update parameters
    w -= learning_rate * dw
    b -= learning_rate * db

    # Optional: print progress every 100 steps
    if i % 100 == 0:
        print(f"Epoch {i}: w={w:.3f}, b={b:.3f}, MSE={mse(y, y_pred):.3f}")
# Out:
# Epoch 0: w=1.426, b=0.217, MSE=152.015
# Epoch 100: w=2.023, b=0.638, MSE=0.877
# Epoch 200: w=1.993, b=0.833, MSE=0.837
# Epoch 300: w=1.976, b=0.951, MSE=0.823
# Epoch 400: w=1.965, b=1.022, MSE=0.817
# Epoch 500: w=1.959, b=1.065, MSE=0.815
# Epoch 600: w=1.955, b=1.091, MSE=0.815
# Epoch 700: w=1.952, b=1.106, MSE=0.815
# Epoch 800: w=1.951, b=1.116, MSE=0.814
# Epoch 900: w=1.950, b=1.122, MSE=0.814

# %%
y_pred_final = w * X + b

plt.scatter(X, y, label='Data')
plt.plot(X, y_pred_final, color='red', label='Best Fit Line')
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()

print(f"Final Model: y = {w:.2f}x + {b:.2f}")
# Out:
# Final Model: y = 1.95x + 1.12

# %%
final_mse = mse(y, y_pred_final)
print(f"Final Mean Squared Error: {final_mse:.3f}")
# Out:
# Final Mean Squared Error: 0.814
